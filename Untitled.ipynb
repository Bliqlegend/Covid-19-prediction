# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %%
recovered_cases=pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
confirmed_cases=pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
deaths=pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
cases_country=pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_country.csv')

# %%
confirmed_cases.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '8/30/20', '8/31/20', '9/1/20', '9/2/20', '9/3/20', '9/4/20', '9/5/20',
#        '9/6/20', '9/7/20', '9/8/20'],
#       dtype='object', length=235)

# %%
cases_country.shape
# Out:
# (188, 14)

# %%
confirmed_cases.shape
# Out:
# (266, 235)

# %%
confirmed_cases=confirmed_cases.replace(np.nan,' ',regex=True)
cases_country=cases_country.replace(np.nan,' ',regex=True)
deaths=deaths.replace(np.nan,' ',regex=True)
recovered_cases=recovered_cases.replace(np.nan,' ',regex=True)

# %%
confirmed_cases[confirmed_cases["Country/Region"]=="India"]
# Out:
#     Province/State Country/Region        Lat      Long  1/22/20  1/23/20  \
# 143                         India  20.593684  78.96288        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  8/30/20  8/31/20   9/1/20  \
# 143        0        0        0        0  ...  3621245  3691166  3769523
#
#       9/2/20   9/3/20   9/4/20   9/5/20   9/6/20   9/7/20   9/8/20
# 143  3853406  3936747  4023179  4113811  4204613  4280422  4370128
#
# [1 rows x 235 columns]

# %%
confirmed_cases
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0                          Afghanistan  33.939110  67.709953        0
# 1                              Albania  41.153300  20.168300        0
# 2                              Algeria  28.033900   1.659600        0
# 3                              Andorra  42.506300   1.521800        0
# 4                               Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 261                 West Bank and Gaza  31.952200  35.233200        0
# 262                     Western Sahara  24.215500 -12.885800        0
# 263                              Yemen  15.552727  48.516388        0
# 264                             Zambia -13.133897  27.849332        0
# 265                           Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  8/30/20  8/31/20  \
# ...

# %%
cases_country.columns
# Out:
# Index(['Country_Region', 'Last_Update', 'Lat', 'Long_', 'Confirmed', 'Deaths',
#        'Recovered', 'Active', 'Incident_Rate', 'People_Tested',
#        'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3'],
#       dtype='object')

# %%
cases_country
# Out:
#          Country_Region          Last_Update      Lat    Long_  Confirmed  \
# 0           Afghanistan  2020-09-09 12:28:54  33.9391    67.71    38544.0
# 1               Albania  2020-09-09 12:28:54  41.1533  20.1683    10553.0
# 2               Algeria  2020-09-09 12:28:54  28.0339   1.6596    46938.0
# 3               Andorra  2020-09-09 12:28:54  42.5063   1.5218     1261.0
# 4                Angola  2020-09-09 12:28:54 -11.2027  17.8739     3033.0
# ..                  ...                  ...      ...      ...        ...
# 183  West Bank and Gaza  2020-09-09 12:28:54  31.9522  35.2332    27919.0
# 184      Western Sahara  2020-09-09 12:28:54  24.2155 -12.8858       10.0
# 185               Yemen  2020-09-09 12:28:54  15.5527  48.5164     1994.0
# 186              Zambia  2020-09-09 12:28:54 -13.1339  27.8493    12952.0
# 187            Zimbabwe  2020-09-09 12:28:54 -19.0154  29.1549     7388.0
#
#      Deaths Recovered   Active Incident_Rate People_Tested  \
# ...

# %%
global_cases=cases_country[['Confirmed','Deaths','Recovered','Active']]
global_data=pd.DataFrame(global_cases.sum()).transpose()
global_data.style.format("{:,.0f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_13458c9a_f29a_11ea_b5ec_ea9eb413aadd" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>        <th class="col_heading level0 col1" >Deaths</th>        <th class="col_heading level0 col2" >Active</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_13458c9a_f29a_11ea_b5ec_ea9eb413aaddlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_13458c9a_f29a_11ea_b5ec_ea9eb413aaddrow0_col0" class="data row0 col0" >27,610,660</td>
#                         <td id="T_13458c9a_f29a_11ea_b5ec_ea9eb413aaddrow0_col1" class="data row0 col1" >898,297</td>
#                         <td id="T_13458c9a_f29a_11ea_b5ec_ea9eb413aaddrow0_col2" class="data row0 col2" >8,144,829</td>
#             </tr>
#     </tbody></table>

# %%
confirmed_ts=confirmed_cases.copy().drop(['Province/State','Country/Region','Lat','Long'],axis=1)

# %%
confirmed_ts_summary=confirmed_ts.sum()

# %%
confirmed_ts_summary
# Out:
# 1/22/20         555
# 1/23/20         654
# 1/24/20         941
# 1/25/20        1434
# 1/26/20        2118
#              ...
# 9/4/20     26617971
# 9/5/20     26881547
# 9/6/20     27103845
# 9/7/20     27337760
# 9/8/20     27570742
# Length: 231, dtype: int64

# %%
fig_1=go.Figure(data=go.Scatter(x=confirmed_ts_summary.index,y=confirmed_ts_summary.values,mode='lines+markers'))
fig_1.update_layout(title="Total Confirmed cases (globally)",yaxis_title='Confirmed Cases',xaxis_tickangle=315)
fig_1.show()
# Out:
# <div>
#
#
#             <div id="de1c5709-5c6f-477a-b30d-95aa5d1250c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("de1c5709-5c6f-477a-b30d-95aa5d1250c7")) {
#                     Plotly.newPlot(
#                         'de1c5709-5c6f-477a-b30d-95aa5d1250c7',
# ...

# %%
cases_country[['Country_Region','Confirmed','Deaths','Recovered','Active']].sort_values(by='Confirmed',ascending=False).reset_index(drop=True).style.bar(align="left",width=98)
# Out:
# <style  type="text/css" >
#     #T_1624358c_f29a_11ea_be31_ea9eb413aaddrow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.0%, transparent 98.0%);
#         }    #T_1624358c_f29a_11ea_be31_ea9eb413aaddrow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.0%, transparent 98.0%);
#         }    #T_1624358c_f29a_11ea_be31_ea9eb413aaddrow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 98.0%, transparent 98.0%);
#         }    #T_1624358c_f29a_11ea_be31_ea9eb413aaddrow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 67.7%, transparent 67.7%);
#         }    #T_1624358c_f29a_11ea_be31_ea9eb413aaddrow1_col2 {
#             width:  10em;
#              height:  80%;
# ...

# %%
country='India'
confirmed_india=confirmed_cases[confirmed_cases['Country/Region']==country]
confirmed_india=confirmed_india.drop(["Province/State",'Lat','Long','Country/Region'],axis=1)

deaths_india=deaths[deaths['Country/Region']==country]
deaths_india=deaths_india.drop(["Province/State",'Lat','Long','Country/Region'],axis=1)

recovered_india=recovered_cases[recovered_cases['Country/Region']==country]
recovered_india=recovered_india.drop(["Province/State",'Lat','Long','Country/Region'],axis=1)
confirmed_india.columns
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '8/30/20', '8/31/20', '9/1/20', '9/2/20', '9/3/20', '9/4/20', '9/5/20',
#        '9/6/20', '9/7/20', '9/8/20'],
#       dtype='object', length=231)

# %%
confirmed_india_ts=confirmed_india.reset_index(drop=True).sum()
recovered_india_ts=recovered_india.reset_index(drop=True).sum()
deaths_india_ts=deaths_india.reset_index(drop=True).sum()
active_india_ts=pd.Series(np.array([x1-x2-x3 for (x1,x2,x3) in zip(confirmed_india_ts,recovered_india_ts,deaths_india_ts)]),index=confirmed_india_ts.index)

# %%
india_array=[confirmed_india_ts,recovered_india_ts,deaths_india_ts,active_india_ts]
labels=["Confirmed",'Recovered','Deaths','Active']
color_arr=px.colors.qualitative.Dark24

# %%
#draw_plot(india_array)
#plt.plot(confirmed_india_ts,color='red',marker='o',linewidth=1,markersize=5)
#plt.plot(recovered_india_ts)
#plt.plot(deaths_india_ts)
#plt.plot(active_india_ts)
fig_1=go.Figure(data=go.Scatter(x=confirmed_india_ts.index,y=confirmed_india_ts.values,mode='lines+markers'))
fig_1.update_layout(title="Total Confirmed cases (globally)",yaxis_title='Confirmed Cases',xaxis_tickangle=315)
fig_1.show()
# Out:
# <div>
#
#
#             <div id="605fcbac-470b-4909-aee0-9d3706fea716" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("605fcbac-470b-4909-aee0-9d3706fea716")) {
#                     Plotly.newPlot(
#                         '605fcbac-470b-4909-aee0-9d3706fea716',
# ...

# %%
fig=go.Figure()
pos=0
for i in india_array:
    fig.add_trace(go.Scatter(x=i.index,y=i.values,name=labels[pos]))
    pos+=1
fig.update_layout(title="Total Cases (India)",xaxis_title='Cases from January to September',yaxis_title='Total Cases',xaxis_tickangle=315)
fig.show()
# Out:
# <div>
#
#
#             <div id="8d5f3cd5-ca10-4a44-93b5-4bef5ac01aab" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8d5f3cd5-ca10-4a44-93b5-4bef5ac01aab")) {
#                     Plotly.newPlot(
#                         '8d5f3cd5-ca10-4a44-93b5-4bef5ac01aab',
# ...
